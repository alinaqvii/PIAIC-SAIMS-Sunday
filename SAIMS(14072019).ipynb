# %% [markdown]
# # File Handling

# %%
with open('abc.txt', 'w') as file_object:
    file_object.write('Hello PIAIC')

# %%
with open('xyz.txt', 'r') as asad:
    x = asad.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8413f827a9e2> in <module>
# ----> 1 with open('xyz.txt', 'r') as asad:
#       2     x = asad.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyz.txt'

# %%
with open('abc.txt', 'r') as asad:
    x = asad.read()  

print(x)
# Out:
# Hello PIAIC

# %%
with open('abc.txt', 'w') as asad:
    asad.write('Hello Ada Lovlace')

# %%
with open('abc.txt', 'r') as asad:
    x = asad.read()  

print(x)
# Out:
# Hello Ada Lovlace

# %%
with open('abc.txt', 'a') as asad:
    asad.write('Hello PIAIC')

# %%
with open('abc.txt', 'r') as asad:
    x = asad.read()  

print(x)
# Out:
# Hello Ada LovlaceHello PIAIC

# %% [raw]
#     name    cell_no    cnic
#     hamza   737y3738   763576387692
#
#    wajahat 478478     4794893

# %%
with open('Data.txt', 'w') as asad:
    asad.write('name \t\t\t Cnic \t\t\t Number')

# %%
# Out:
# name 			 Cnic 			 Number

# %%
for i in range(0,3):
    name = input("Enter your name: ")
    no = input("Enter your number: ")
    cn = input("Enter your Cnic: ")

    with open('Data.txt', 'a') as asad:
        asad.write(f'{name} \t\t\t {no} \t\t\t Number {cn}\n')
# Out:
# Enter your name: a
# Enter your number: a
# Enter your Cnic: a
# Enter your name: a
# Enter your number: a
# Enter your Cnic: a
# Enter your name: a
# Enter your number: a
# Enter your Cnic: a

# %%
with open('Data.txt', 'r') as asad:
    data = asad.read()

# %%
print(data)
# Out:
# name 			 Cnic 			 Numbera 			 a 			 Number a
# a 			 a 			 Number a
# a 			 a 			 Number a

# %%
with open('abc.txt', 'w') as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-26-32675abc2ef3> in <module>
#       1 with open('abc.txt', 'w') as file:
# ----> 2     print(file.read())
#
# UnsupportedOperation: not readable

# %%
with open('abc.txt', 'w') as file:
    file.write('Hello World')

# %%
with open('abc.txt', 'r+') as file:
    print(file.read())
# Out:
# Hello World

# %%
with open('xyz.txt', 'r+') as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-eac5c8476f61> in <module>
# ----> 1 with open('xyz.txt', 'r+') as file:
#       2     print(file.read())
#       3
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyz.txt'

# %%
with open('abc.txt', 'r+') as file:
    print(file.read())
    file.write('Hello Asad')
# Out:
# Hello World

# %%
with open('abc.txt', 'r+') as file:
    
    file.write('Hello Asad')
    file.seek(0)
    print(file.read())
# Out:
# Hello Asad
